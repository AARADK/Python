# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading CSV files using Pandas

# %%
PATH = "tourist_arrival.csv"  # Please adjust your PATH and filename accordingly

df = pd.read_csv(PATH)# read the csv file  and display the data 
print(df)
# Out:
#     Year   Jan.   Feb.   Mar.   Apr.   May.   Jun.   Jul.   Aug.   Sep.  \
# 0   1992  17451  27489  31505  30682  29089  22469  20942  27338  24839
# 1   1993  19238  23931  30818  20121  20585  19602  13588  21583  23939
# 2   1994  21735  24872  31586  27292  26232  22907  19739  27610  27959
# 3   1995  22207  28240  34219  33994  27843  25650  23980  27686  30569
# 4   1996  27886  29676  39336  36331  29728  26749  22684  29080  32181
# 5   1997  25585  32861  43177  35229  33456  26367  26091  35549  31981
# 6   1998  28822  37956  41338  41087  35814  29181  27895  36174  39664
# 7   1999  29752  38134  46218  40774  42712  31049  27193  38449  44117
# 8   2000  25307  38959  44944  43635  28363  26933  24480  34670  43523
# 9   2001  30454  38680  46709  39083  28345  13030  18329  25322  31170
# 10  2002  17176  20668  28815  21253  19887  17218  16621  21093  23752
# 11  2003  21215  24349  27737  25851  22704  20351  22661  27568  28724
# 12  2004  30988  35631  44290  33514  26802  19793  24860  33162  25496
# 13  2005  25477  20338  29875  23414  25541  22608  23996  36910  36066
# 14  2006  28769  25728  36873  21983  22870  26210  25183  33150  33362
# 15  2007  33192  39934  54722  40942  35854  31316  35437  44683  45552
# 16  2008  36913  46675  58735  38475  30410  24349  25427  40011  41622
# 17  2009  29278  40617  49567  43337  30037  31749  30432  44174  42771
# 18  2010  33645  49264  63058  45509  32542  33263  38991  54672  54848
# 19  2011  42622  56339  67565  59751  46202  46115  42661  71398  63033
# 20  2012  52501  66459  89151  69796  50317  53630  49995  71964  66383
# 21  2013  47846  67264  88697  65152  52834  54599  54011  68478  66755
#
#      Oct.   Nov.   Dec.   Total
# 0   42647  32341  27561  334353
# 1   42242  30378  27542  293567
# 2   39393  28008  29198  326531
# 3   46845  35782  26380  363395
# 4   47314  37650  34998  393613
# 5   56272  40173  35116  421857
# 6   62487  47403  35863  463684
# 7   66543  48865  37698  491504
# 8   59195  52993  40644  463646
# 9   41245  30282  18588  361237
# 10  35272  28723  24990  275468
# 11  45459  38398  33115  338132
# 12  43373  36381  31007  385297
# 13  51498  41505  38170  375398
# 14  49670  44119  36009  383926
# 15  70644  52273  42156  526705
# 16  66421  52399  38840  500277
# 17  72522  54423  41049  509956
# 18  79130  67537  50408  602867
# 19  96996  83460  60073  736215
# 20  86379  83173  63344  803092
# 21  99426  75485  57069  797616

# %%
month=['Jan','Feb','Mar','Apr','May','Jun','Jul,','Aug','Sep','Oct','Nov','Dec'] # put all the month in the list in  a order
month
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul,',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
mean_of_every_month_tourists_arrival=[df['Jan.'].mean(),df['Feb.'].mean(),df['Mar.'].mean(),df['Apr.'].mean(),df['May.'].mean(),df['Jun.'].mean(),df['Jul.'].mean(),df['Aug.'].mean(),df['Sep.'].mean(),df['Oct.'].mean(),df['Nov.'].mean(),df['Dec.'].mean()] #calculate the mean of the data of all the season
mean_of_every_month_tourists_arrival
# Out:
# [29457.227272727272,
#  37002.90909090909,
#  46769.77272727273,
#  38054.77272727273,
#  31734.863636363636,
#  28415.363636363636,
#  27963.454545454544,
#  38669.27272727273,
#  39013.90909090909,
#  59135.13636363636,
#  47352.318181818184,
#  37719.0]

# %%
plt.bar(month,mean_of_every_month_tourists_arrival) 
plt.show()# this function show the bar chart

# %%
plt.bar(month,mean_of_every_month_tourists_arrival)
plt.xlabel("Average of months(Jan-Dec)") # label the x-axis 
plt.ylabel("Numbers of tourist") #label the y axis
# Out:
# Text(0, 0.5, 'Numbers of tourist')

# %% [markdown]
# question no 2:

# %%
#spring(march,april,may)
spring=df['Mar.'].mean()+df['Apr.'].mean()+df['May.'].mean()  # calcutae the mean of specific month
spring
# Out:
# 116559.40909090909

# %%
#summer(june,july,august)
summer=df['Jun.'].mean()+df['Jul.'].mean()+df['Aug.'].mean() # calcutae the mean of specific month
summer
# Out:
# 95048.09090909091

# %%
#autumn(september,october,november)
autum=df['Sep.'].mean()+df['Oct.'].mean()+df['Nov.'].mean() # calcutae the mean of specific month
autum
# Out:
# 145501.36363636362

# %%
#winter(december,january,feburary)
winter=df['Dec.'].mean()+df['Jan.'].mean()+df['Feb.'].mean() # calcutae the mean of specific month
winter
# Out:
# 104179.13636363635

# %%
all_season=['spring','summer','autumn','winter']   #store the values in list 
mean_of_season=[spring,summer,autum,winter]

# %%
plt.bar(all_season,mean_of_season) # Plot the bar of specific data store in a list 
plt.xlabel('Name of all season')
plt.ylabel('Mean of season')
plt.show()

# %% [markdown]
# So, the most popular season for tourist arrival is  Autumn and least popular season for tourist arrival is Summer.

# %% [markdown]
# Question no: 3

# %%
(output["Year"].astype(str) + " " +output["Month"]).tolist()[:5]
# Out:
# ['2001 Jun.', '1993 Jul.', '2002 Jul.', '2002 Jan.', '2002 Jun.']
